# %%
import numpy as np
from PIL import Image
from ImageLab import *

# %%
orange1 = Image.open('Image/2mode.jpg').convert('RGB')
orange1 = np.asarray(orange1)
orange2 = Image.open('Image/3mode.jpg').convert('RGB')
orange2 = np.asarray(orange2)

orange1 = ColorSpace(orange1).rgb_to_grayscale()
orange2 = ColorSpace(orange2).rgb_to_grayscale()

g_orange1 = NoiseOverlay(orange1).add_gaussian_noise(40, 40)
g_orange2 = NoiseOverlay(orange2).add_gaussian_noise(40, 40)

# %%
# masks = Segment(g_orange1, '2mode').segment_image(distance=4, width=4)
# masks = Segment(g_orange2, '3mode').segment_image(distance=4, width=4)

# %%
# _,_=Segment(orange1, '2mode').global_threshold(mode = 'median')
# _,_=Segment(orange2, '3mode').global_threshold(mode = 'median')

# %%
# masks = Segment(g_orange1, '2mode').global_multiple_threshold([60, 95, 175])
# masks = Segment(g_orange2, '3mode').global_multiple_threshold([25,100,145,180])

# %%
# for i in range(10, 50, 10):
#     image = Segment(g_orange1, '2mode_g').adaptive_threshold_segmentation(n=i, background_difference=70)
    #image = Segment(g_orange2, '3mode_g').adaptive_threshold_segmentation(
    #    n=i, background_difference=70)

# %%
# name = '2mode_g'
# image = np.copy(g_orange1)
# for i in range(3, 15, 3):
    
#     ImagePlotter(image).plot_image_with_histogram(
#         title=f'{name}')
#     img1 = Segment(
#         image, f'{name}_Niblack_n={i}').Pixel_Filter(window_size=i, function=Segment().Niblack)
#     img2 = Segment(
#         image, f'{name}_Sauvola_n={i}').Pixel_Filter(window_size=i, function=Segment().Sauvola)
#     img3 = Segment(image, f'{name}_Bernsen_n={i}').Pixel_Filter(window_size=i, function=Segment().Bernsen)

# %%
# name = '2mode_g'
# image = np.copy(g_orange1)
# for i in range(3, 15, 3):

#     ImagePlotter(image).plot_image_with_histogram(
#         title=f'{name}')
#     img1 = Segment(
#         image, f'{name}_Niblack_n={i}').Pixel_Filter(window_size=i, function=Segment().Niblack)
#     img2 = Segment(
#         image, f'{name}_Sauvola_n={i}').Pixel_Filter(window_size=i, function=Segment().Sauvola)
#     img3 = Segment(image, f'{name}_Bernsen_n={i}').Pixel_Filter(
#         window_size=i, function=Segment().Bernsen)

# %%
orange1 = Image.open('Image/2mode.jpg').convert('RGB')
orange1 = np.asarray(orange1)
orange1 = NoiseOverlay(orange1).add_gaussian_noise(40, 40)

name = '2mode'
image = np.copy(orange1)
for i in range(3, 15, 3):

    ImagePlotter(image).plot_image_with_histogram(
        title=f'{name}')
    img1 = Segment(
        image, f'{name}_Niblack_n={i}').Pixel_Filter(window_size=i, function=Segment().Niblack)
    img2 = Segment(
        image, f'{name}_Sauvola_n={i}').Pixel_Filter(window_size=i, function=Segment().Sauvola)
    img3 = Segment(image, f'{name}_Bernsen_n={i}').Pixel_Filter(
        window_size=i, function=Segment().Bernsen)
