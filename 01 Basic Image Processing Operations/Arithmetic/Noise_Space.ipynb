# %%
from noisegenerators import NoiseOverlay
from imageutils import ImageUtils
from colorspace import ColorSpace

from PIL import Image

# Open the image in RGB format
orange1 = Image.open('Image/orange1.jpg').convert('RGB')

# Open the image in RGB format
orange2 = Image.open('Image/orange2.jpg').convert('RGB')

# Open the image in RGB format
orange3 = Image.open('Image/orange3.jpg').convert('RGB')

# Open the image in RGB format
orange4 = Image.open('Image/orange4.jpg').convert('RGB')

# %%
# ImageUtils(NoiseOverlay(orange1).gaussian_noise(15, 40)).plot_image_with_histogram(title = 'Gaussian')

# %%
# ImageUtils(NoiseOverlay(orange1).add_gaussian_noise(15, 40)).plot_image_with_histogram(title='Noisy Gaussian')
# ImageUtils(NoiseOverlay(orange2).add_gaussian_noise(15, 40)).plot_image_with_histogram(title='Noisy Gaussian')
# ImageUtils(NoiseOverlay(orange3).add_gaussian_noise(15, 40)).plot_image_with_histogram(title='Noisy Gaussian')

orange1 = ColorSpace(orange1).rgb_to_HSV()
ImageUtils(orange1).plot_HSV()

# %%
# ImageUtils(orange1).plot_image_with_histogram(title='Original')
# ImageUtils(orange2).plot_image_with_histogram(title='Original')
# ImageUtils(orange3).plot_image_with_histogram(title='Original')

# %%
ImageUtils(NoiseOverlay(orange1).add_salt_and_pepper_noise(0.2, [1], 'noise')).plot_image_with_histogram(title='Salt and Pepper')

# %%
# ImageUtils(NoiseOverlay(orange1).add_salt_and_pepper_noise(0.2, [1,2])).plot_image_with_histogram(title='Noisy Salt and Pepper')
# ImageUtils(NoiseOverlay(orange2).add_salt_and_pepper_noise(0.2, [1,2])).plot_image_with_histogram(title='Noisy Salt and Pepper')
# ImageUtils(NoiseOverlay(orange3).add_salt_and_pepper_noise(0.2, [1,2])).plot_image_with_histogram(title='Noisy Salt and Pepper')

# %%
# Open the image in RGB format
orange1 = Image.open('Image/orange1.jpg').convert('RGB')

# Open the image in RGB format
orange2 = Image.open('Image/orange2.jpg').convert('RGB')

# Open the image in RGB format
orange3 = Image.open('Image/orange3.jpg').convert('RGB')

# Open the image in RGB format
orange4 = Image.open('Image/orange4.jpg').convert('RGB')

orange1 = ColorSpace(orange1).rgb_to_HSV()
orange1 = NoiseOverlay(orange1).add_salt_and_pepper_noise(0.2, [1,2])
orange2 = ColorSpace(orange2).rgb_to_HSV()
orange2 = NoiseOverlay(orange2).add_salt_and_pepper_noise(0.4, [1,2])
orange3 = ColorSpace(orange3).rgb_to_HSV()
orange3 = NoiseOverlay(orange3).add_salt_and_pepper_noise(0.6, [1,2])

ImageUtils(orange1).plot_HSV()
ImageUtils(orange1).plot_HSV_with_histogram('Orange1: 0.2')
ImageUtils(orange2).plot_HSV_with_histogram('Orange2: 0.4')
ImageUtils(orange3).plot_HSV_with_histogram('Orange3: 0.6')

# %%
# Open the image in RGB format
orange1 = Image.open('Image/orange1.jpg').convert('RGB')

# Open the image in RGB format
orange2 = Image.open('Image/orange2.jpg').convert('RGB')

# Open the image in RGB format
orange3 = Image.open('Image/orange3.jpg').convert('RGB')

# Open the image in RGB format
orange4 = Image.open('Image/orange4.jpg').convert('RGB')

orange1 = ColorSpace(orange1).rgb_to_HSV()
orange1 = NoiseOverlay(orange1).add_gaussian_noise(20, 3000, [1, 2])
orange2 = ColorSpace(orange2).rgb_to_HSV()
orange2 = NoiseOverlay(orange2).add_gaussian_noise(20, 6000, [1, 2])
orange3 = ColorSpace(orange3).rgb_to_HSV()
orange3 = NoiseOverlay(orange3).add_gaussian_noise(20, 9000, [1, 2])

ImageUtils(orange1).plot_HSV()
ImageUtils(orange1).plot_HSV_with_histogram('Orange1: 3000')
ImageUtils(orange2).plot_HSV_with_histogram('Orange2: 6000')
ImageUtils(orange3).plot_HSV_with_histogram('Orange3: 9000')

# %%
ImageUtils(orange3).save_image_to_folder('Orange/Noise','O3g9000.png')
# Out:
# 'Orange/Noise\\O3g9000.png'
